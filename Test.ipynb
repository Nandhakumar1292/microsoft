# %% [markdown]
# # Test Run

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing Test Dataset

# %%
df_test = pd.read_csv('/content/drive/MyDrive/Project/4.Microsoft/test_sample.csv')

# %%
df_test.shape
# Out:
# (4147992, 46)

# %%
df_test.head()
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0  1245540519230    657       11767    87199  2024-06-04T22:56:27.000Z
# 1  1400159342154      3       91158   632273  2024-06-03T12:58:26.000Z
# 2  1279900255923    145       32247   131719  2024-06-08T03:20:49.000Z
# 3    60129547292    222       15294   917686  2024-06-12T12:07:31.000Z
# 4   515396080539    363        7615     5944  2024-06-06T17:42:05.000Z
#
#    DetectorId  AlertTitle           Category                  MitreTechniques  \
# 0         524         563    LateralMovement      T1021;T1047;T1105;T1569.002
# 1           2           2  CommandAndControl                              NaN
# 2        2932       10807    LateralMovement  T1021;T1027.002;T1027.005;T1105
# 3           0           0      InitialAccess                  T1078;T1078.004
# 4          27          18          Discovery                  T1087;T1087.002
#
#     IncidentGrade ActionGrouped ActionGranular         EntityType  \
# 0  BenignPositive           NaN            NaN               User
# 1  BenignPositive           NaN            NaN            Machine
# 2  BenignPositive           NaN            NaN            Process
# 3   FalsePositive           NaN            NaN  CloudLogonSession
# 4  BenignPositive           NaN            NaN               User
#
#   EvidenceRole  DeviceId  Sha256  IpAddress     Url  AccountSid  AccountUpn  \
# 0     Impacted     98799  138268     360606  160396        2610        3699
# 1     Impacted      1239  138268     360606  160396      441377      673934
# 2      Related     98799    4296     360606  160396      441377      673934
# 3      Related     98799  138268     360606  160396      441377      673934
# 4     Impacted     98799  138268     360606  160396      133549      673934
#
#    AccountObjectId  AccountName  DeviceName  NetworkMessageId  EmailClusterId  \
# 0           425863          863      153085            529644             NaN
# 1           425863       453297        2833            529644             NaN
# 2           425863       453297      153085            529644             NaN
# 3           425863       453297      153085            529644             NaN
# 4           425863       136104      153085            529644             NaN
#
#    RegistryKey  RegistryValueName  RegistryValueData  ApplicationId  \
# 0         1631                635                860           2251
# 1         1631                635                860           2251
# 2         1631                635                860           2251
# 3         1631                635                860           2251
# 4         1631                635                860           2251
#
#    ApplicationName  OAuthApplicationId ThreatFamily  FileName  FolderPath  \
# 0             3421                 881          NaN    289573      117668
# 1             3421                 881          NaN    289573      117668
# 2             3421                 881          NaN        14          22
# 3             3421                 881          NaN    289573      117668
# 4             3421                 881          NaN    289573      117668
#
#    ResourceIdName ResourceType       Roles  OSFamily  OSVersion  \
# 0            3586          NaN         NaN         5         66
# 1            3586          NaN         NaN         0          0
# 2            3586          NaN         NaN         5         66
# 3            3586          NaN         NaN         5         66
# 4            3586          NaN  Suspicious         5         66
#
#   AntispamDirection SuspicionLevel LastVerdict  CountryCode  State   City  \
# 0               NaN     Suspicious  Suspicious          242   1445  10630
# 1               NaN     Suspicious  Suspicious          242   1445  10630
# 2               NaN     Suspicious  Suspicious          242   1445  10630
# 3               NaN            NaN         NaN          242   1445  10630
# 4               NaN            NaN         NaN          242   1445  10630
#
#      Usage
# 0  Private
# 1   Public
# 2   Public
# 3   Public
# 4   Public

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4147992 entries, 0 to 4147991
# Data columns (total 46 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  int64
#  1   OrgId               int64
#  2   IncidentId          int64
#  3   AlertId             int64
#  4   Timestamp           object
#  5   DetectorId          int64
#  6   AlertTitle          int64
#  7   Category            object
#  8   MitreTechniques     object
#  9   IncidentGrade       object
#  10  ActionGrouped       object
#  11  ActionGranular      object
#  12  EntityType          object
#  13  EvidenceRole        object
#  14  DeviceId            int64
#  15  Sha256              int64
#  16  IpAddress           int64
#  17  Url                 int64
#  18  AccountSid          int64
#  19  AccountUpn          int64
#  20  AccountObjectId     int64
#  21  AccountName         int64
#  22  DeviceName          int64
#  23  NetworkMessageId    int64
#  24  EmailClusterId      float64
#  25  RegistryKey         int64
#  26  RegistryValueName   int64
#  27  RegistryValueData   int64
#  28  ApplicationId       int64
#  29  ApplicationName     int64
#  30  OAuthApplicationId  int64
#  31  ThreatFamily        object
#  32  FileName            int64
#  33  FolderPath          int64
#  34  ResourceIdName      int64
#  35  ResourceType        object
#  36  Roles               object
#  37  OSFamily            int64
#  38  OSVersion           int64
#  39  AntispamDirection   object
#  40  SuspicionLevel      object
#  41  LastVerdict         object
#  42  CountryCode         int64
#  43  State               int64
#  44  City                int64
#  45  Usage               object
# dtypes: float64(1), int64(30), object(15)
# memory usage: 1.4+ GB

# %%
df_test.describe()
# Out:
#                  Id         OrgId    IncidentId       AlertId    DetectorId  \
# count  4.147992e+06  4.147992e+06  4.147992e+06  4.147992e+06  4.147992e+06
# mean   8.462250e+11  1.756698e+02  6.780345e+04  4.072191e+05  1.008391e+02
# std    4.923351e+11  3.708729e+02  1.178736e+05  4.550578e+05  4.082934e+02
# min    1.000000e+00  0.000000e+00  3.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.209068e+11  8.000000e+00  4.110000e+02  2.365900e+04  2.000000e+00
# 50%    8.418136e+11  4.300000e+01  8.818000e+03  2.228970e+05  7.000000e+00
# 75%    1.271310e+12  1.730000e+02  7.944000e+04  6.711010e+05  3.900000e+01
# max    1.709397e+12  6.138000e+03  5.997000e+05  1.721457e+06  9.520000e+03
#
#          AlertTitle      DeviceId        Sha256     IpAddress           Url  \
# count  4.147992e+06  4.147992e+06  4.147992e+06  4.147992e+06  4.147992e+06
# mean   2.529514e+03  9.575061e+04  1.283939e+05  2.873898e+05  1.504279e+05
# std    1.044138e+04  1.615628e+04  3.457595e+04  1.400920e+05  3.734754e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.000000e+00  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
# 50%    9.000000e+00  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
# 75%    1.160000e+02  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
# max    1.131690e+05  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
#
#          AccountSid    AccountUpn  AccountObjectId   AccountName  \
# count  4.147992e+06  4.147992e+06     4.147992e+06  4.147992e+06
# mean   3.532813e+05  4.706754e+05     3.419357e+05  3.582316e+05
# std    1.660976e+05  2.885003e+05     1.595671e+05  1.738693e+05
# min    0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 25%    4.413770e+05  1.015320e+05     4.258630e+05  4.532970e+05
# 50%    4.413770e+05  6.739340e+05     4.258630e+05  4.532970e+05
# 75%    4.413770e+05  6.739340e+05     4.258630e+05  4.532970e+05
# max    4.413770e+05  6.739340e+05     4.258630e+05  4.532970e+05
#
#          DeviceName  NetworkMessageId  EmailClusterId   RegistryKey  \
# count  4.147992e+06      4.147992e+06    4.170700e+04  4.147992e+06
# mean   1.417392e+05      4.834652e+05    3.231065e+09  1.627532e+03
# std    3.868470e+04      1.368565e+05    1.043861e+09  7.382003e+01
# min    0.000000e+00      0.000000e+00    1.927080e+05  0.000000e+00
# 25%    1.530850e+05      5.296440e+05    2.688174e+09  1.631000e+03
# 50%    1.530850e+05      5.296440e+05    3.492818e+09  1.631000e+03
# 75%    1.530850e+05      5.296440e+05    4.108874e+09  1.631000e+03
# max    1.530850e+05      5.296440e+05    4.294964e+09  1.631000e+03
#
#        RegistryValueName  RegistryValueData  ApplicationId  ApplicationName  \
# count       4.147992e+06       4.147992e+06   4.147992e+06     4.147992e+06
# mean        6.345193e+02       8.592115e+02   2.200962e+03     3.342993e+03
# std         1.721417e+01       2.552240e+01   3.313870e+02     5.096996e+02
# min         0.000000e+00       0.000000e+00   0.000000e+00     0.000000e+00
# 25%         6.350000e+02       8.600000e+02   2.251000e+03     3.421000e+03
# 50%         6.350000e+02       8.600000e+02   2.251000e+03     3.421000e+03
# 75%         6.350000e+02       8.600000e+02   2.251000e+03     3.421000e+03
# max         6.350000e+02       8.600000e+02   2.251000e+03     3.421000e+03
#
#        OAuthApplicationId      FileName    FolderPath  ResourceIdName  \
# count        4.147992e+06  4.147992e+06  4.147992e+06    4.147992e+06
# mean         8.808119e+02  2.618998e+05  1.074020e+05    3.583541e+03
# std          1.238317e+01  8.208434e+04  3.260346e+04    9.012124e+01
# min          0.000000e+00  0.000000e+00  0.000000e+00    0.000000e+00
# 25%          8.810000e+02  2.895730e+05  1.176680e+05    3.586000e+03
# 50%          8.810000e+02  2.895730e+05  1.176680e+05    3.586000e+03
# 75%          8.810000e+02  2.895730e+05  1.176680e+05    3.586000e+03
# max          8.810000e+02  2.895730e+05  1.176680e+05    3.586000e+03
#
#            OSFamily     OSVersion   CountryCode         State          City
# count  4.147992e+06  4.147992e+06  4.147992e+06  4.147992e+06  4.147992e+06
# mean   4.899529e+00  6.466873e+01  2.222218e+02  1.344570e+03  9.883839e+03
# std    7.001299e-01  9.269678e+00  6.499822e+01  3.626851e+02  2.696302e+03
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03  1.063000e+04
# 50%    5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03  1.063000e+04
# 75%    5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03  1.063000e+04
# max    5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03  1.063000e+04

# %% [markdown]
# ## Data Cleaning and Data Preprocessing

# %%
null_values_in_cent = pd.DataFrame({
    'Null_values_Count' : df_test.isnull().sum(),
    'Null_values_Percentage' : df_test.isnull().sum()/len(df_test)*100
})

null_values_in_cent
# Out:
#                     Null_values_Count  Null_values_Percentage
# Id                                  0                0.000000
# OrgId                               0                0.000000
# IncidentId                          0                0.000000
# AlertId                             0                0.000000
# Timestamp                           0                0.000000
# DetectorId                          0                0.000000
# AlertTitle                          0                0.000000
# Category                            0                0.000000
# MitreTechniques               2307104               55.619779
# IncidentGrade                       0                0.000000
# ActionGrouped                 4146079               99.953881
# ActionGranular                4146079               99.953881
# EntityType                          0                0.000000
# EvidenceRole                        0                0.000000
# DeviceId                            0                0.000000
# Sha256                              0                0.000000
# IpAddress                           0                0.000000
# Url                                 0                0.000000
# AccountSid                          0                0.000000
# AccountUpn                          0                0.000000
# AccountObjectId                     0                0.000000
# AccountName                         0                0.000000
# DeviceName                          0                0.000000
# NetworkMessageId                    0                0.000000
# EmailClusterId                4106285               98.994526
# RegistryKey                         0                0.000000
# RegistryValueName                   0                0.000000
# RegistryValueData                   0                0.000000
# ApplicationId                       0                0.000000
# ApplicationName                     0                0.000000
# OAuthApplicationId                  0                0.000000
# ThreatFamily                  4116614               99.243538
# FileName                            0                0.000000
# FolderPath                          0                0.000000
# ResourceIdName                      0                0.000000
# ResourceType                  4144998               99.927820
# Roles                         4039317               97.380058
# OSFamily                            0                0.000000
# OSVersion                           0                0.000000
# AntispamDirection             4071481               98.155469
# SuspicionLevel                3498157               84.333745
# LastVerdict                   3155260               76.067167
# CountryCode                         0                0.000000
# State                               0                0.000000
# City                                0                0.000000
# Usage                               0                0.000000

# %%
# Removing 50% of the Null values
threshold= len(df_test)* 0.5
df_test = df_test.dropna(thresh=threshold,axis=1)

# %%
df_test.shape
# Out:
# (4147992, 36)

# %%
df_test.isnull().sum()
# Out:
# Id                    0
# OrgId                 0
# IncidentId            0
# AlertId               0
# Timestamp             0
# DetectorId            0
# AlertTitle            0
# Category              0
# IncidentGrade         0
# EntityType            0
# EvidenceRole          0
# DeviceId              0
# Sha256                0
# IpAddress             0
# Url                   0
# AccountSid            0
# AccountUpn            0
# AccountObjectId       0
# AccountName           0
# DeviceName            0
# NetworkMessageId      0
# RegistryKey           0
# RegistryValueName     0
# RegistryValueData     0
# ApplicationId         0
# ApplicationName       0
# OAuthApplicationId    0
# FileName              0
# FolderPath            0
# ResourceIdName        0
# OSFamily              0
# OSVersion             0
# CountryCode           0
# State                 0
# City                  0
# Usage                 0
# dtype: int64

# %%
df_test.duplicated().sum()
# Out:
# 225297

# %%
df_test = df_test.drop_duplicates()
df_test.duplicated().sum()
# Out:
# 0

# %%
df_test.isnull().sum()
# Out:
# Id                    0
# OrgId                 0
# IncidentId            0
# AlertId               0
# Timestamp             0
# DetectorId            0
# AlertTitle            0
# Category              0
# IncidentGrade         0
# EntityType            0
# EvidenceRole          0
# DeviceId              0
# Sha256                0
# IpAddress             0
# Url                   0
# AccountSid            0
# AccountUpn            0
# AccountObjectId       0
# AccountName           0
# DeviceName            0
# NetworkMessageId      0
# RegistryKey           0
# RegistryValueName     0
# RegistryValueData     0
# ApplicationId         0
# ApplicationName       0
# OAuthApplicationId    0
# FileName              0
# FolderPath            0
# ResourceIdName        0
# OSFamily              0
# OSVersion             0
# CountryCode           0
# State                 0
# City                  0
# Usage                 0
# dtype: int64

# %% [markdown]
# ### Changing the Dype

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3922695 entries, 0 to 4147990
# Data columns (total 36 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  int64
#  1   OrgId               int64
#  2   IncidentId          int64
#  3   AlertId             int64
#  4   Timestamp           object
#  5   DetectorId          int64
#  6   AlertTitle          int64
#  7   Category            object
#  8   IncidentGrade       object
#  9   EntityType          object
#  10  EvidenceRole        object
#  11  DeviceId            int64
#  12  Sha256              int64
#  13  IpAddress           int64
#  14  Url                 int64
#  15  AccountSid          int64
#  16  AccountUpn          int64
#  17  AccountObjectId     int64
#  18  AccountName         int64
#  19  DeviceName          int64
#  20  NetworkMessageId    int64
#  21  RegistryKey         int64
#  22  RegistryValueName   int64
#  23  RegistryValueData   int64
#  24  ApplicationId       int64
#  25  ApplicationName     int64
#  26  OAuthApplicationId  int64
#  27  FileName            int64
#  28  FolderPath          int64
#  29  ResourceIdName      int64
#  30  OSFamily            int64
#  31  OSVersion           int64
#  32  CountryCode         int64
#  33  State               int64
#  34  City                int64
#  35  Usage               object
# dtypes: int64(30), object(6)
# memory usage: 1.1+ GB

# %%
df_test['Timestamp'] = pd.to_datetime(df_test['Timestamp'])
df_test['Timestamp'].dtype
# Out:
# datetime64[ns, UTC]

# %%
df_test['Day'] = df_test['Timestamp'].dt.day
df_test['Month'] = df_test['Timestamp'].dt.month
df_test['Year'] = df_test['Timestamp'].dt.year
df_test['Hour'] = df_test['Timestamp'].dt.hour
df_test['Time'] = df_test['Timestamp'].dt.time

# %%
df_test = df_test.drop('Timestamp', axis=1)

# %%
df_test
# Out:
#                     Id  OrgId  IncidentId  AlertId  DetectorId  AlertTitle  \
# 0        1245540519230    657       11767    87199         524         563
# 1        1400159342154      3       91158   632273           2           2
# 2        1279900255923    145       32247   131719        2932       10807
# 3          60129547292    222       15294   917686           0           0
# 4         515396080539    363        7615     5944          27          18
# ...                ...    ...         ...      ...         ...         ...
# 4147985   171798692464     42         391   638112         135        7322
# 4147987   541165881145    262        3017   227156         139         120
# 4147988   438086666953   1323       31001   304819         219         196
# 4147989  1297080124487     47        3653     7243          57          29
# 4147990   627065226886     70        4243    19142           1           1
#
#                   Category   IncidentGrade         EntityType EvidenceRole  \
# 0          LateralMovement  BenignPositive               User     Impacted
# 1        CommandAndControl  BenignPositive            Machine     Impacted
# 2          LateralMovement  BenignPositive            Process      Related
# 3            InitialAccess   FalsePositive  CloudLogonSession      Related
# 4                Discovery  BenignPositive               User     Impacted
# ...                    ...             ...                ...          ...
# 4147985            Malware  BenignPositive            Machine     Impacted
# 4147987      InitialAccess  BenignPositive               User     Impacted
# 4147988      InitialAccess  BenignPositive               User     Impacted
# 4147989  CommandAndControl   FalsePositive                 Ip      Related
# 4147990      InitialAccess  BenignPositive            Mailbox     Impacted
#
#          DeviceId  Sha256  IpAddress     Url  AccountSid  AccountUpn  \
# 0           98799  138268     360606  160396        2610        3699
# 1            1239  138268     360606  160396      441377      673934
# 2           98799    4296     360606  160396      441377      673934
# 3           98799  138268     360606  160396      441377      673934
# 4           98799  138268     360606  160396      133549      673934
# ...           ...     ...        ...     ...         ...         ...
# 4147985         4  138268     360606  160396      441377      673934
# 4147987     98799  138268     360606  160396       13354       13012
# 4147988     98799  138268     360606  160396       95744      172717
# 4147989     98799  138268       1084  160396      441377      673934
# 4147990     98799  138268     360606  160396       53146       59351
#
#          AccountObjectId  AccountName  DeviceName  NetworkMessageId  \
# 0                 425863          863      153085            529644
# 1                 425863       453297        2833            529644
# 2                 425863       453297      153085            529644
# 3                 425863       453297      153085            529644
# 4                 425863       136104      153085            529644
# ...                  ...          ...         ...               ...
# 4147985           425863       453297           4            529644
# 4147987            13489        14567      153085            529644
# 4147988            96809       107151      153085            529644
# 4147989           425863       453297      153085            529644
# 4147990            53421        25428      153085            529644
#
#          RegistryKey  RegistryValueName  RegistryValueData  ApplicationId  \
# 0               1631                635                860           2251
# 1               1631                635                860           2251
# 2               1631                635                860           2251
# 3               1631                635                860           2251
# 4               1631                635                860           2251
# ...              ...                ...                ...            ...
# 4147985         1631                635                860           2251
# 4147987         1631                635                860           2251
# 4147988         1631                635                860           2251
# 4147989         1631                635                860           2251
# 4147990         1631                635                860           2251
#
#          ApplicationName  OAuthApplicationId  FileName  FolderPath  \
# 0                   3421                 881    289573      117668
# 1                   3421                 881    289573      117668
# 2                   3421                 881        14          22
# 3                   3421                 881    289573      117668
# 4                   3421                 881    289573      117668
# ...                  ...                 ...       ...         ...
# 4147985             3421                 881    289573      117668
# 4147987             3421                 881    289573      117668
# 4147988             3421                 881    289573      117668
# 4147989             3421                 881    289573      117668
# 4147990             3421                 881    289573      117668
#
#          ResourceIdName  OSFamily  OSVersion  CountryCode  State   City  \
# 0                  3586         5         66          242   1445  10630
# 1                  3586         0          0          242   1445  10630
# 2                  3586         5         66          242   1445  10630
# 3                  3586         5         66          242   1445  10630
# 4                  3586         5         66          242   1445  10630
# ...                 ...       ...        ...          ...    ...    ...
# 4147985            3586         0          0          242   1445  10630
# 4147987            3586         5         66          242   1445  10630
# 4147988            3586         5         66          242   1445  10630
# 4147989            3586         5         66          242   1445  10630
# 4147990            3586         5         66          242   1445  10630
#
#            Usage  Day  Month  Year  Hour      Time
# 0        Private    4      6  2024    22  22:56:27
# 1         Public    3      6  2024    12  12:58:26
# 2         Public    8      6  2024     3  03:20:49
# 3         Public   12      6  2024    12  12:07:31
# 4         Public    6      6  2024    17  17:42:05
# ...          ...  ...    ...   ...   ...       ...
# 4147985   Public    3      6  2024    20  20:24:41
# 4147987   Public    4      6  2024     3  03:53:15
# 4147988  Private    4      6  2024    19  19:32:19
# 4147989   Public   15      6  2024     0  00:50:22
# 4147990  Private   11      6  2024    16  16:18:12
#
# [3922695 rows x 40 columns]

# %% [markdown]
# ### Checking Categorical Columns

# %%
categorical_cols = df_test.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# Index(['Category', 'IncidentGrade', 'EntityType', 'EvidenceRole', 'Usage',
#        'Time'],
#       dtype='object')

# %%
df_test[categorical_cols].describe()
# Out:
#              Category   IncidentGrade EntityType EvidenceRole    Usage  \
# count         3922695         3922695    3922695      3922695  3922695
# unique             19               3         29            2        2
# top     InitialAccess  BenignPositive         Ip      Related   Public
# freq          1730207         1630942     929595      2121700  2756700
#
#             Time
# count    3922695
# unique     86329
# top     22:02:45
# freq       11318

# %%
df_test['Usage'].unique()
# Out:
# array(['Private', 'Public'], dtype=object)

# %%
df_test['Usage'].value_counts()
# Out:
# Usage
# Public     2756700
# Private    1165995
# Name: count, dtype: int64

# %%
# Usage Column does not provide any important and relevant values.. so dropping this column
df_test = df_test.drop('Usage', axis=1)

# %%
df_test['EvidenceRole'].value_counts()
# Out:
# EvidenceRole
# Related     2121700
# Impacted    1800995
# Name: count, dtype: int64

# %%
df_test['IncidentGrade'].value_counts()
# Out:
# IncidentGrade
# BenignPositive    1630942
# TruePositive      1422856
# FalsePositive      868897
# Name: count, dtype: int64

# %% [markdown]
# ## EDA

# %%
for col in df_test.columns:
  print(f"{col} : {df_test[col].nunique()}")
# Out:
# Id : 303220
# OrgId : 4400
# IncidentId : 236267
# AlertId : 637320
# DetectorId : 5970
# AlertTitle : 42265
# Category : 19
# IncidentGrade : 3
# EntityType : 29
# EvidenceRole : 2
# DeviceId : 46260
# Sha256 : 59446
# IpAddress : 173786
# Url : 65600
# AccountSid : 215737
# AccountUpn : 311996
# AccountObjectId : 204666
# AccountName : 222314
# DeviceName : 74791
# NetworkMessageId : 181759
# RegistryKey : 995
# RegistryValueName : 255
# RegistryValueData : 492
# ApplicationId : 951
# ApplicationName : 1514
# OAuthApplicationId : 380
# FileName : 122200
# FolderPath : 43970
# ResourceIdName : 1109
# OSFamily : 5
# OSVersion : 43
# CountryCode : 212
# State : 1159
# City : 6637
# Day : 31
# Month : 8
# Year : 2
# Hour : 24
# Time : 86329

# %%
df_test.columns
# Out:
# Index(['Id', 'OrgId', 'IncidentId', 'AlertId', 'DetectorId', 'AlertTitle',
#        'Category', 'IncidentGrade', 'EntityType', 'EvidenceRole', 'DeviceId',
#        'Sha256', 'IpAddress', 'Url', 'AccountSid', 'AccountUpn',
#        'AccountObjectId', 'AccountName', 'DeviceName', 'NetworkMessageId',
#        'RegistryKey', 'RegistryValueName', 'RegistryValueData',
#        'ApplicationId', 'ApplicationName', 'OAuthApplicationId', 'FileName',
#        'FolderPath', 'ResourceIdName', 'OSFamily', 'OSVersion', 'CountryCode',
#        'State', 'City', 'Day', 'Month', 'Year', 'Hour', 'Time'],
#       dtype='object')

# %%
categorical_columns = ['Category', 'IncidentGrade', 'EntityType', 'EvidenceRole']
# Plot each categorical column separately
for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=column, data=df_test, palette='cividis')
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Count")
    plt.xticks(rotation=90)
    plt.show()

# %%
# Aggregate data
hour_incident_grade = df_test.groupby(['Hour', 'IncidentGrade']).size().unstack()
day_incident_grade = df_test.groupby(['Day', 'IncidentGrade']).size().unstack()
month_incident_grade = df_test.groupby(['Month', 'IncidentGrade']).size().unstack()
year_incident_grade = df_test.groupby(['Year', 'IncidentGrade']).size().unstack()

# Hourly distribution (stacked bar plot)
plt.figure(figsize=(12, 6))
hour_incident_grade.plot(kind='bar', stacked=True, colormap='viridis')
plt.title("IncidentGrade Counts Across Hours of the Day")
plt.xlabel("Hour of the Day")
plt.ylabel("Count")
plt.legend(title='IncidentGrade')
plt.grid(True)
plt.show()

# Daily distribution (stacked bar plot)
plt.figure(figsize=(12, 6))
day_incident_grade.plot(kind='bar', stacked=True, colormap='viridis')
plt.title("IncidentGrade Counts Across Days of the Month")
plt.xlabel("Day of the Month")
plt.ylabel("Count")
plt.legend(title='IncidentGrade')
plt.grid(True)
plt.show()

# Monthly distribution (stacked bar plot)
plt.figure(figsize=(12, 6))
month_incident_grade.plot(kind='bar', stacked=True, colormap='viridis')
plt.title("IncidentGrade Counts Across Months of the Year")
plt.xlabel("Month")
plt.ylabel("Count")
plt.legend(title='IncidentGrade')
plt.grid(True)
plt.show()

# Year distribution (staked bar plot)
plt.figure(figsize=(12, 6))
year_incident_grade.plot(kind='bar', stacked=True, colormap='viridis')
plt.title("IncidentGrade Counts Across Years")
plt.xlabel("Year")
plt.ylabel("Count")
plt.legend(title='IncidentGrade')
plt.grid(True)
plt.show()

# %%
# selecting numerical col
numeric_df = df_test.select_dtypes(include=['number'])

corr_matrix= numeric_df.corr().abs()

# plot the heatmap
plt.figure(figsize=(20,15))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, linewidths=0.5)
plt.title('correlation Heatmap')
plt.show()

# %%
# removing unwanted columns like ID and timedate dased for model training
# i kept some of the name because to know whether where the spam mail comes from
selected_columns = [
    'AlertTitle', 'Category', 'EvidenceRole', 'EntityType', 'OSFamily', 'CountryCode',
    'Url', 'AccountName','DeviceName', 'IncidentGrade']
df_test = df_test[selected_columns]

# %%
df_test.shape
# Out:
# (3922695, 10)

# %%
df_test.head(1)
# Out:
#    AlertTitle         Category EvidenceRole EntityType  OSFamily  CountryCode  \
# 0         563  LateralMovement     Impacted       User         5          242
#
#       Url  AccountName  DeviceName   IncidentGrade
# 0  160396          863      153085  BenignPositive

# %% [markdown]
# ## Encoding

# %%
df_test.head()
# Out:
#    AlertTitle           Category EvidenceRole         EntityType  OSFamily  \
# 0         563    LateralMovement     Impacted               User         5
# 1           2  CommandAndControl     Impacted            Machine         0
# 2       10807    LateralMovement      Related            Process         5
# 3           0      InitialAccess      Related  CloudLogonSession         5
# 4          18          Discovery     Impacted               User         5
#
#    CountryCode     Url  AccountName  DeviceName   IncidentGrade
# 0          242  160396          863      153085  BenignPositive
# 1          242  160396       453297        2833  BenignPositive
# 2          242  160396       453297      153085  BenignPositive
# 3          242  160396       453297      153085   FalsePositive
# 4          242  160396       136104      153085  BenignPositive

# %%
categorical_columns = ['AlertTitle', 'Category', 'EntityType', 'EvidenceRole',
       'Url', 'AccountName', 'DeviceName', 'OSFamily', 'CountryCode']

# %%
# List of columns to process
columns_to_group = ['AlertTitle', 'Url', 'AccountName', 'DeviceName', 'CountryCode']

# Looping through each column and grouping the less frequent values into "Others"
for column in columns_to_group:
    category_counts = df_test[column].value_counts()
    top_categories = category_counts.nlargest(5).index
    df_test[column] = df_test[column].where(df_test[column].isin(top_categories), 'Others')

# Now verifing the changes
df_test
# Out:
#         AlertTitle           Category EvidenceRole         EntityType  \
# 0           Others    LateralMovement     Impacted               User
# 1                2  CommandAndControl     Impacted            Machine
# 2           Others    LateralMovement      Related            Process
# 3                0      InitialAccess      Related  CloudLogonSession
# 4           Others          Discovery     Impacted               User
# ...            ...                ...          ...                ...
# 4147985     Others            Malware     Impacted            Machine
# 4147987     Others      InitialAccess     Impacted               User
# 4147988     Others      InitialAccess     Impacted               User
# 4147989     Others  CommandAndControl      Related                 Ip
# 4147990          1      InitialAccess     Impacted            Mailbox
#
#          OSFamily CountryCode     Url AccountName DeviceName   IncidentGrade
# 0               5         242  160396      Others     153085  BenignPositive
# 1               0         242  160396      453297     Others  BenignPositive
# 2               5         242  160396      453297     153085  BenignPositive
# 3               5         242  160396      453297     153085   FalsePositive
# 4               5         242  160396      Others     153085  BenignPositive
# ...           ...         ...     ...         ...        ...             ...
# 4147985         0         242  160396      453297          4  BenignPositive
# 4147987         5         242  160396      Others     153085  BenignPositive
# 4147988         5         242  160396      Others     153085  BenignPositive
# 4147989         5         242  160396      453297     153085   FalsePositive
# 4147990         5         242  160396      Others     153085  BenignPositive
#
# [3922695 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_test['IncidentGrade'] = le.fit_transform(df_test['IncidentGrade'])


# One-Hot Encoding for nominal features
df_test = pd.get_dummies(df_test, columns=categorical_columns, drop_first=True)

# %%
df_test.shape
# Out:
# (3922695, 77)

# %%
df_test.head()
# Out:
#    IncidentGrade  AlertTitle_1  AlertTitle_2  AlertTitle_3  AlertTitle_4  \
# 0              0         False         False         False         False
# 1              0         False          True         False         False
# 2              0         False         False         False         False
# 3              1         False         False         False         False
# 4              0         False         False         False         False
#
#    AlertTitle_Others  Category_CommandAndControl  Category_CredentialAccess  \
# 0               True                       False                      False
# 1              False                        True                      False
# 2               True                       False                      False
# 3              False                       False                      False
# 4               True                       False                      False
#
#    Category_CredentialStealing  Category_DefenseEvasion  Category_Discovery  \
# 0                        False                    False               False
# 1                        False                    False               False
# 2                        False                    False               False
# 3                        False                    False               False
# 4                        False                    False                True
#
#    Category_Execution  Category_Exfiltration  Category_Exploit  \
# 0               False                  False             False
# 1               False                  False             False
# 2               False                  False             False
# 3               False                  False             False
# 4               False                  False             False
#
#    Category_Impact  Category_InitialAccess  Category_LateralMovement  \
# 0            False                   False                      True
# 1            False                   False                     False
# 2            False                   False                      True
# 3            False                    True                     False
# 4            False                   False                     False
#
#    Category_Malware  Category_Persistence  Category_PrivilegeEscalation  \
# 0             False                 False                         False
# 1             False                 False                         False
# 2             False                 False                         False
# 3             False                 False                         False
# 4             False                 False                         False
#
#    Category_Ransomware  Category_SuspiciousActivity  \
# 0                False                        False
# 1                False                        False
# 2                False                        False
# 3                False                        False
# 4                False                        False
#
#    Category_UnwantedSoftware  Category_WebExploit  EntityType_AmazonResource  \
# 0                      False                False                      False
# 1                      False                False                      False
# 2                      False                False                      False
# 3                      False                False                      False
# 4                      False                False                      False
#
#    EntityType_AzureResource  EntityType_Blob  EntityType_BlobContainer  \
# 0                     False            False                     False
# 1                     False            False                     False
# 2                     False            False                     False
# 3                     False            False                     False
# 4                     False            False                     False
#
#    EntityType_CloudApplication  EntityType_CloudLogonRequest  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    EntityType_CloudLogonSession  EntityType_File  EntityType_GenericEntity  \
# 0                         False            False                     False
# 1                         False            False                     False
# 2                         False            False                     False
# 3                          True            False                     False
# 4                         False            False                     False
#
#    EntityType_GoogleCloudResource  EntityType_IoTDevice  EntityType_Ip  \
# 0                           False                 False          False
# 1                           False                 False          False
# 2                           False                 False          False
# 3                           False                 False          False
# 4                           False                 False          False
#
#    EntityType_KubernetesCluster  EntityType_KubernetesNamespace  \
# 0                         False                           False
# 1                         False                           False
# 2                         False                           False
# 3                         False                           False
# 4                         False                           False
#
#    EntityType_Machine  EntityType_MailCluster  EntityType_MailMessage  \
# 0               False                   False                   False
# 1                True                   False                   False
# 2               False                   False                   False
# 3               False                   False                   False
# 4               False                   False                   False
#
#    EntityType_Mailbox  EntityType_MailboxConfiguration  EntityType_Malware  \
# 0               False                            False               False
# 1               False                            False               False
# 2               False                            False               False
# 3               False                            False               False
# 4               False                            False               False
#
#    EntityType_Nic  EntityType_OAuthApplication  EntityType_Process  \
# 0           False                        False               False
# 1           False                        False               False
# 2           False                        False                True
# 3           False                        False               False
# 4           False                        False               False
#
#    EntityType_RegistryKey  EntityType_RegistryValue  EntityType_SecurityGroup  \
# 0                   False                     False                     False
# 1                   False                     False                     False
# 2                   False                     False                     False
# 3                   False                     False                     False
# 4                   False                     False                     False
#
#    EntityType_Url  EntityType_User  EvidenceRole_Related  Url_1  Url_2  Url_5  \
# 0           False             True                 False  False  False  False
# 1           False            False                 False  False  False  False
# 2           False            False                  True  False  False  False
# 3           False            False                  True  False  False  False
# 4           False             True                 False  False  False  False
#
#    Url_160396  Url_Others  AccountName_1  AccountName_2  AccountName_10  \
# 0        True       False          False          False           False
# 1        True       False          False          False           False
# 2        True       False          False          False           False
# 3        True       False          False          False           False
# 4        True       False          False          False           False
#
#    AccountName_453297  AccountName_Others  DeviceName_1  DeviceName_4  \
# 0               False                True         False         False
# 1                True               False         False         False
# 2                True               False         False         False
# 3                True               False         False         False
# 4               False                True         False         False
#
#    DeviceName_6  DeviceName_153085  DeviceName_Others  OSFamily_1  OSFamily_2  \
# 0         False               True              False       False       False
# 1         False              False               True       False       False
# 2         False               True              False       False       False
# 3         False               True              False       False       False
# 4         False               True              False       False       False
#
#    OSFamily_3  OSFamily_5  CountryCode_1  CountryCode_2  CountryCode_3  \
# 0       False        True          False          False          False
# 1       False       False          False          False          False
# 2       False        True          False          False          False
# 3       False        True          False          False          False
# 4       False        True          False          False          False
#
#    CountryCode_242  CountryCode_Others
# 0             True               False
# 1             True               False
# 2             True               False
# 3             True               False
# 4             True               False

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3922695 entries, 0 to 4147990
# Data columns (total 77 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   IncidentGrade                    int64
#  1   AlertTitle_1                     bool
#  2   AlertTitle_2                     bool
#  3   AlertTitle_3                     bool
#  4   AlertTitle_4                     bool
#  5   AlertTitle_Others                bool
#  6   Category_CommandAndControl       bool
#  7   Category_CredentialAccess        bool
#  8   Category_CredentialStealing      bool
#  9   Category_DefenseEvasion          bool
#  10  Category_Discovery               bool
#  11  Category_Execution               bool
#  12  Category_Exfiltration            bool
#  13  Category_Exploit                 bool
#  14  Category_Impact                  bool
#  15  Category_InitialAccess           bool
#  16  Category_LateralMovement         bool
#  17  Category_Malware                 bool
#  18  Category_Persistence             bool
#  19  Category_PrivilegeEscalation     bool
#  20  Category_Ransomware              bool
#  21  Category_SuspiciousActivity      bool
#  22  Category_UnwantedSoftware        bool
#  23  Category_WebExploit              bool
#  24  EntityType_AmazonResource        bool
#  25  EntityType_AzureResource         bool
#  26  EntityType_Blob                  bool
#  27  EntityType_BlobContainer         bool
#  28  EntityType_CloudApplication      bool
#  29  EntityType_CloudLogonRequest     bool
#  30  EntityType_CloudLogonSession     bool
#  31  EntityType_File                  bool
#  32  EntityType_GenericEntity         bool
#  33  EntityType_GoogleCloudResource   bool
#  34  EntityType_IoTDevice             bool
#  35  EntityType_Ip                    bool
#  36  EntityType_KubernetesCluster     bool
#  37  EntityType_KubernetesNamespace   bool
#  38  EntityType_Machine               bool
#  39  EntityType_MailCluster           bool
#  40  EntityType_MailMessage           bool
#  41  EntityType_Mailbox               bool
#  42  EntityType_MailboxConfiguration  bool
#  43  EntityType_Malware               bool
#  44  EntityType_Nic                   bool
#  45  EntityType_OAuthApplication      bool
#  46  EntityType_Process               bool
#  47  EntityType_RegistryKey           bool
#  48  EntityType_RegistryValue         bool
#  49  EntityType_SecurityGroup         bool
#  50  EntityType_Url                   bool
#  51  EntityType_User                  bool
#  52  EvidenceRole_Related             bool
#  53  Url_1                            bool
#  54  Url_2                            bool
#  55  Url_5                            bool
#  56  Url_160396                       bool
#  57  Url_Others                       bool
#  58  AccountName_1                    bool
#  59  AccountName_2                    bool
#  60  AccountName_10                   bool
#  61  AccountName_453297               bool
#  62  AccountName_Others               bool
#  63  DeviceName_1                     bool
#  64  DeviceName_4                     bool
#  65  DeviceName_6                     bool
#  66  DeviceName_153085                bool
#  67  DeviceName_Others                bool
#  68  OSFamily_1                       bool
#  69  OSFamily_2                       bool
#  70  OSFamily_3                       bool
#  71  OSFamily_5                       bool
#  72  CountryCode_1                    bool
#  73  CountryCode_2                    bool
#  74  CountryCode_3                    bool
#  75  CountryCode_242                  bool
#  76  CountryCode_Others               bool
# dtypes: bool(76), int64(1)
# memory usage: 344.2 MB

# %% [markdown]
# ## Saving this TestDataset in joblib

# %%
df_test = df_test.reset_index(drop=True)

# %%
import joblib
joblib.dump(df_test, '/content/drive/MyDrive/Project/4.Microsoft/encoded_test_data.joblib')
# Out:
# ['/content/drive/MyDrive/Project/4.Microsoft/encoded_test_data.joblib']

# %%
df_test = joblib.load('/content/drive/MyDrive/Project/4.Microsoft/encoded_test_data.joblib')
df_test.head()
# Out:
#    IncidentGrade  AlertTitle_1  AlertTitle_2  AlertTitle_3  AlertTitle_4  \
# 0              0         False         False         False         False
# 1              0         False          True         False         False
# 2              0         False         False         False         False
# 3              1         False         False         False         False
# 4              0         False         False         False         False
#
#    AlertTitle_Others  Category_CommandAndControl  Category_CredentialAccess  \
# 0               True                       False                      False
# 1              False                        True                      False
# 2               True                       False                      False
# 3              False                       False                      False
# 4               True                       False                      False
#
#    Category_CredentialStealing  Category_DefenseEvasion  Category_Discovery  \
# 0                        False                    False               False
# 1                        False                    False               False
# 2                        False                    False               False
# 3                        False                    False               False
# 4                        False                    False                True
#
#    Category_Execution  Category_Exfiltration  Category_Exploit  \
# 0               False                  False             False
# 1               False                  False             False
# 2               False                  False             False
# 3               False                  False             False
# 4               False                  False             False
#
#    Category_Impact  Category_InitialAccess  Category_LateralMovement  \
# 0            False                   False                      True
# 1            False                   False                     False
# 2            False                   False                      True
# 3            False                    True                     False
# 4            False                   False                     False
#
#    Category_Malware  Category_Persistence  Category_PrivilegeEscalation  \
# 0             False                 False                         False
# 1             False                 False                         False
# 2             False                 False                         False
# 3             False                 False                         False
# 4             False                 False                         False
#
#    Category_Ransomware  Category_SuspiciousActivity  \
# 0                False                        False
# 1                False                        False
# 2                False                        False
# 3                False                        False
# 4                False                        False
#
#    Category_UnwantedSoftware  Category_WebExploit  EntityType_AmazonResource  \
# 0                      False                False                      False
# 1                      False                False                      False
# 2                      False                False                      False
# 3                      False                False                      False
# 4                      False                False                      False
#
#    EntityType_AzureResource  EntityType_Blob  EntityType_BlobContainer  \
# 0                     False            False                     False
# 1                     False            False                     False
# 2                     False            False                     False
# 3                     False            False                     False
# 4                     False            False                     False
#
#    EntityType_CloudApplication  EntityType_CloudLogonRequest  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    EntityType_CloudLogonSession  EntityType_File  EntityType_GenericEntity  \
# 0                         False            False                     False
# 1                         False            False                     False
# 2                         False            False                     False
# 3                          True            False                     False
# 4                         False            False                     False
#
#    EntityType_GoogleCloudResource  EntityType_IoTDevice  EntityType_Ip  \
# 0                           False                 False          False
# 1                           False                 False          False
# 2                           False                 False          False
# 3                           False                 False          False
# 4                           False                 False          False
#
#    EntityType_KubernetesCluster  EntityType_KubernetesNamespace  \
# 0                         False                           False
# 1                         False                           False
# 2                         False                           False
# 3                         False                           False
# 4                         False                           False
#
#    EntityType_Machine  EntityType_MailCluster  EntityType_MailMessage  \
# 0               False                   False                   False
# 1                True                   False                   False
# 2               False                   False                   False
# 3               False                   False                   False
# 4               False                   False                   False
#
#    EntityType_Mailbox  EntityType_MailboxConfiguration  EntityType_Malware  \
# 0               False                            False               False
# 1               False                            False               False
# 2               False                            False               False
# 3               False                            False               False
# 4               False                            False               False
#
#    EntityType_Nic  EntityType_OAuthApplication  EntityType_Process  \
# 0           False                        False               False
# 1           False                        False               False
# 2           False                        False                True
# 3           False                        False               False
# 4           False                        False               False
#
#    EntityType_RegistryKey  EntityType_RegistryValue  EntityType_SecurityGroup  \
# 0                   False                     False                     False
# 1                   False                     False                     False
# 2                   False                     False                     False
# 3                   False                     False                     False
# 4                   False                     False                     False
#
#    EntityType_Url  EntityType_User  EvidenceRole_Related  Url_1  Url_2  Url_5  \
# 0           False             True                 False  False  False  False
# 1           False            False                 False  False  False  False
# 2           False            False                  True  False  False  False
# 3           False            False                  True  False  False  False
# 4           False             True                 False  False  False  False
#
#    Url_160396  Url_Others  AccountName_1  AccountName_2  AccountName_10  \
# 0        True       False          False          False           False
# 1        True       False          False          False           False
# 2        True       False          False          False           False
# 3        True       False          False          False           False
# 4        True       False          False          False           False
#
#    AccountName_453297  AccountName_Others  DeviceName_1  DeviceName_4  \
# 0               False                True         False         False
# 1                True               False         False         False
# 2                True               False         False         False
# 3                True               False         False         False
# 4               False                True         False         False
#
#    DeviceName_6  DeviceName_153085  DeviceName_Others  OSFamily_1  OSFamily_2  \
# 0         False               True              False       False       False
# 1         False              False               True       False       False
# 2         False               True              False       False       False
# 3         False               True              False       False       False
# 4         False               True              False       False       False
#
#    OSFamily_3  OSFamily_5  CountryCode_1  CountryCode_2  CountryCode_3  \
# 0       False        True          False          False          False
# 1       False       False          False          False          False
# 2       False        True          False          False          False
# 3       False        True          False          False          False
# 4       False        True          False          False          False
#
#    CountryCode_242  CountryCode_Others
# 0             True               False
# 1             True               False
# 2             True               False
# 3             True               False
# 4             True               False

# %%
df_train = joblib.load('/content/drive/MyDrive/Project/4.Microsoft/encoded_train_data.joblib')
df_train.head()
# Out:
#    IncidentGrade  AlertTitle_1  AlertTitle_2  AlertTitle_3  AlertTitle_4  \
# 0              0         False         False         False         False
# 1              0         False         False         False         False
# 2              0         False         False         False         False
# 3              2         False         False         False         False
# 4              0         False         False         False         False
#
#    AlertTitle_Others  Category_CommandAndControl  Category_CredentialAccess  \
# 0               True                       False                      False
# 1               True                       False                      False
# 2               True                       False                      False
# 3               True                       False                      False
# 4               True                       False                      False
#
#    Category_CredentialStealing  Category_DefenseEvasion  Category_Discovery  \
# 0                        False                    False               False
# 1                        False                    False               False
# 2                        False                    False               False
# 3                        False                    False               False
# 4                        False                    False               False
#
#    Category_Execution  Category_Exfiltration  Category_Exploit  \
# 0               False                  False             False
# 1               False                  False             False
# 2                True                  False             False
# 3               False                  False             False
# 4               False                   True             False
#
#    Category_Impact  Category_InitialAccess  Category_LateralMovement  \
# 0            False                   False                     False
# 1             True                   False                     False
# 2            False                   False                     False
# 3            False                   False                     False
# 4            False                   False                     False
#
#    Category_Malware  Category_Persistence  Category_PrivilegeEscalation  \
# 0              True                 False                         False
# 1             False                 False                         False
# 2             False                 False                         False
# 3             False                 False                         False
# 4             False                 False                         False
#
#    Category_Ransomware  Category_SuspiciousActivity  \
# 0                False                        False
# 1                False                        False
# 2                False                        False
# 3                False                         True
# 4                False                        False
#
#    Category_UnwantedSoftware  Category_Weaponization  Category_WebExploit  \
# 0                      False                   False                False
# 1                      False                   False                False
# 2                      False                   False                False
# 3                      False                   False                False
# 4                      False                   False                False
#
#    EntityType_AmazonResource  EntityType_AzureResource  EntityType_Blob  \
# 0                      False                     False            False
# 1                      False                     False            False
# 2                      False                     False            False
# 3                      False                     False            False
# 4                      False                     False            False
#
#    EntityType_BlobContainer  EntityType_CloudApplication  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
#
#    EntityType_CloudLogonRequest  EntityType_CloudLogonSession  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
#
#    EntityType_ContainerRegistry  EntityType_File  EntityType_GenericEntity  \
# 0                         False             True                     False
# 1                         False            False                     False
# 2                         False            False                     False
# 3                         False             True                     False
# 4                         False             True                     False
#
#    EntityType_GoogleCloudResource  EntityType_IoTDevice  EntityType_Ip  \
# 0                           False                 False          False
# 1                           False                 False          False
# 2                           False                 False          False
# 3                           False                 False          False
# 4                           False                 False          False
#
#    EntityType_KubernetesCluster  EntityType_KubernetesNamespace  \
# 0                         False                           False
# 1                         False                           False
# 2                         False                           False
# 3                         False                           False
# 4                         False                           False
#
#    EntityType_KubernetesPod  EntityType_Machine  EntityType_MailCluster  \
# 0                     False               False                   False
# 1                     False                True                   False
# 2                     False                True                   False
# 3                     False               False                   False
# 4                     False               False                   False
#
#    EntityType_MailMessage  EntityType_Mailbox  \
# 0                   False               False
# 1                   False               False
# 2                   False               False
# 3                   False               False
# 4                   False               False
#
#    EntityType_MailboxConfiguration  EntityType_Malware  EntityType_Nic  \
# 0                            False               False           False
# 1                            False               False           False
# 2                            False               False           False
# 3                            False               False           False
# 4                            False               False           False
#
#    EntityType_OAuthApplication  EntityType_Process  EntityType_RegistryKey  \
# 0                        False               False                   False
# 1                        False               False                   False
# 2                        False               False                   False
# 3                        False               False                   False
# 4                        False               False                   False
#
#    EntityType_RegistryValue  EntityType_SecurityGroup  EntityType_Url  \
# 0                     False                     False           False
# 1                     False                     False           False
# 2                     False                     False           False
# 3                     False                     False           False
# 4                     False                     False           False
#
#    EntityType_User  EvidenceRole_Related  Url_1  Url_2  Url_6  Url_160396  \
# 0            False                  True  False  False  False        True
# 1            False                 False  False  False  False        True
# 2            False                 False  False  False  False        True
# 3            False                  True  False  False  False        True
# 4            False                 False  False  False  False        True
#
#    Url_Others  AccountName_1  AccountName_2  AccountName_3  \
# 0       False          False          False          False
# 1       False          False          False          False
# 2       False          False          False          False
# 3       False          False          False          False
# 4       False          False          False          False
#
#    AccountName_453297  AccountName_Others  DeviceName_1  DeviceName_4  \
# 0                True               False         False         False
# 1                True               False         False         False
# 2                True               False         False         False
# 3                True               False         False         False
# 4                True               False         False         False
#
#    DeviceName_5  DeviceName_153085  DeviceName_Others  OSFamily_1  OSFamily_2  \
# 0         False               True              False       False       False
# 1         False              False               True       False       False
# 2         False              False               True       False       False
# 3         False               True              False       False       False
# 4         False               True              False       False       False
#
#    OSFamily_3  OSFamily_4  OSFamily_5  CountryCode_1  CountryCode_2  \
# 0       False       False        True          False          False
# 1       False       False        True          False          False
# 2       False       False        True          False          False
# 3       False       False        True          False          False
# 4       False       False        True          False          False
#
#    CountryCode_4  CountryCode_242  CountryCode_Others
# 0          False             True               False
# 1          False             True               False
# 2          False             True               False
# 3          False             True               False
# 4          False             True               False

# %%
df_train.shape
# Out:
# (4577400, 81)

# %%
set(df_train.columns) - set(df_test.columns)
# Out:
# {'AccountName_3',
#  'Category_Weaponization',
#  'CountryCode_4',
#  'DeviceName_5',
#  'EntityType_ContainerRegistry',
#  'EntityType_KubernetesPod',
#  'OSFamily_4',
#  'Url_6'}

# %%
set(df_train.columns) - set(df_test.columns)
# Out:
# set()

# %%
set(df_test.columns) - set(df_train.columns)
# Out:
# {'AccountName_10', 'CountryCode_3', 'DeviceName_6', 'Url_5'}

# %%
cols_to_drop = {'AccountName_10', 'CountryCode_3', 'DeviceName_6', 'Url_5'}
df_test = df_test.drop(columns=cols_to_drop, errors='ignore')

# %%
import joblib
joblib.dump(df_test, '/content/drive/MyDrive/Project/4.Microsoft/encoded_test_data.joblib')
# Out:
# ['/content/drive/MyDrive/Project/4.Microsoft/encoded_test_data.joblib']

# %%
df_test = joblib.load('/content/drive/MyDrive/Project/4.Microsoft/encoded_test_data.joblib')
df_test.head()
# Out:
#    IncidentGrade  AlertTitle_1  AlertTitle_2  AlertTitle_3  AlertTitle_4  \
# 0              0         False         False         False         False
# 1              0         False          True         False         False
# 2              0         False         False         False         False
# 3              1         False         False         False         False
# 4              0         False         False         False         False
#
#    AlertTitle_Others  Category_CommandAndControl  Category_CredentialAccess  \
# 0               True                       False                      False
# 1              False                        True                      False
# 2               True                       False                      False
# 3              False                       False                      False
# 4               True                       False                      False
#
#    Category_CredentialStealing  Category_DefenseEvasion  Category_Discovery  \
# 0                        False                    False               False
# 1                        False                    False               False
# 2                        False                    False               False
# 3                        False                    False               False
# 4                        False                    False                True
#
#    Category_Execution  Category_Exfiltration  Category_Exploit  \
# 0               False                  False             False
# 1               False                  False             False
# 2               False                  False             False
# 3               False                  False             False
# 4               False                  False             False
#
#    Category_Impact  Category_InitialAccess  Category_LateralMovement  \
# 0            False                   False                      True
# 1            False                   False                     False
# 2            False                   False                      True
# 3            False                    True                     False
# 4            False                   False                     False
#
#    Category_Malware  Category_Persistence  Category_PrivilegeEscalation  \
# 0             False                 False                         False
# 1             False                 False                         False
# 2             False                 False                         False
# 3             False                 False                         False
# 4             False                 False                         False
#
#    Category_Ransomware  Category_SuspiciousActivity  \
# 0                False                        False
# 1                False                        False
# 2                False                        False
# 3                False                        False
# 4                False                        False
#
#    Category_UnwantedSoftware  Category_WebExploit  EntityType_AmazonResource  \
# 0                      False                False                      False
# 1                      False                False                      False
# 2                      False                False                      False
# 3                      False                False                      False
# 4                      False                False                      False
#
#    EntityType_AzureResource  EntityType_Blob  EntityType_BlobContainer  \
# 0                     False            False                     False
# 1                     False            False                     False
# 2                     False            False                     False
# 3                     False            False                     False
# 4                     False            False                     False
#
#    EntityType_CloudApplication  EntityType_CloudLogonRequest  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    EntityType_CloudLogonSession  EntityType_File  EntityType_GenericEntity  \
# 0                         False            False                     False
# 1                         False            False                     False
# 2                         False            False                     False
# 3                          True            False                     False
# 4                         False            False                     False
#
#    EntityType_GoogleCloudResource  EntityType_IoTDevice  EntityType_Ip  \
# 0                           False                 False          False
# 1                           False                 False          False
# 2                           False                 False          False
# 3                           False                 False          False
# 4                           False                 False          False
#
#    EntityType_KubernetesCluster  EntityType_KubernetesNamespace  \
# 0                         False                           False
# 1                         False                           False
# 2                         False                           False
# 3                         False                           False
# 4                         False                           False
#
#    EntityType_Machine  EntityType_MailCluster  EntityType_MailMessage  \
# 0               False                   False                   False
# 1                True                   False                   False
# 2               False                   False                   False
# 3               False                   False                   False
# 4               False                   False                   False
#
#    EntityType_Mailbox  EntityType_MailboxConfiguration  EntityType_Malware  \
# 0               False                            False               False
# 1               False                            False               False
# 2               False                            False               False
# 3               False                            False               False
# 4               False                            False               False
#
#    EntityType_Nic  EntityType_OAuthApplication  EntityType_Process  \
# 0           False                        False               False
# 1           False                        False               False
# 2           False                        False                True
# 3           False                        False               False
# 4           False                        False               False
#
#    EntityType_RegistryKey  EntityType_RegistryValue  EntityType_SecurityGroup  \
# 0                   False                     False                     False
# 1                   False                     False                     False
# 2                   False                     False                     False
# 3                   False                     False                     False
# 4                   False                     False                     False
#
#    EntityType_Url  EntityType_User  EvidenceRole_Related  Url_1  Url_2  \
# 0           False             True                 False  False  False
# 1           False            False                 False  False  False
# 2           False            False                  True  False  False
# 3           False            False                  True  False  False
# 4           False             True                 False  False  False
#
#    Url_160396  Url_Others  AccountName_1  AccountName_2  AccountName_453297  \
# 0        True       False          False          False               False
# 1        True       False          False          False                True
# 2        True       False          False          False                True
# 3        True       False          False          False                True
# 4        True       False          False          False               False
#
#    AccountName_Others  DeviceName_1  DeviceName_4  DeviceName_153085  \
# 0                True         False         False               True
# 1               False         False         False              False
# 2               False         False         False               True
# 3               False         False         False               True
# 4                True         False         False               True
#
#    DeviceName_Others  OSFamily_1  OSFamily_2  OSFamily_3  OSFamily_5  \
# 0              False       False       False       False        True
# 1               True       False       False       False       False
# 2              False       False       False       False        True
# 3              False       False       False       False        True
# 4              False       False       False       False        True
#
#    CountryCode_1  CountryCode_2  CountryCode_242  CountryCode_Others
# 0          False          False             True               False
# 1          False          False             True               False
# 2          False          False             True               False
# 3          False          False             True               False
# 4          False          False             True               False

# %%
cols_to_drop = {'AccountName_3',
                'Category_Weaponization',
                'CountryCode_4',
                'DeviceName_5',
                'EntityType_ContainerRegistry',
                'EntityType_KubernetesPod',
                'OSFamily_4',
                'Url_6'}

df_train = df_train.drop(columns=cols_to_drop, errors='ignore')

# %%
df_test.shape
# Out:
# (3922695, 73)

# %%
import joblib
joblib.dump(df_train, '/content/drive/MyDrive/Project/4.Microsoft/encoded_train_data.joblib')
# Out:
# ['/content/drive/MyDrive/Project/4.Microsoft/encoded_train_data.joblib']

# %%
df_train = joblib.load('/content/drive/MyDrive/Project/4.Microsoft/encoded_train_data.joblib')
df_train.head()
# Out:
#    IncidentGrade  AlertTitle_1  AlertTitle_2  AlertTitle_3  AlertTitle_4  \
# 0              0         False         False         False         False
# 1              0         False         False         False         False
# 2              0         False         False         False         False
# 3              2         False         False         False         False
# 4              0         False         False         False         False
#
#    AlertTitle_Others  Category_CommandAndControl  Category_CredentialAccess  \
# 0               True                       False                      False
# 1               True                       False                      False
# 2               True                       False                      False
# 3               True                       False                      False
# 4               True                       False                      False
#
#    Category_CredentialStealing  Category_DefenseEvasion  Category_Discovery  \
# 0                        False                    False               False
# 1                        False                    False               False
# 2                        False                    False               False
# 3                        False                    False               False
# 4                        False                    False               False
#
#    Category_Execution  Category_Exfiltration  Category_Exploit  \
# 0               False                  False             False
# 1               False                  False             False
# 2                True                  False             False
# 3               False                  False             False
# 4               False                   True             False
#
#    Category_Impact  Category_InitialAccess  Category_LateralMovement  \
# 0            False                   False                     False
# 1             True                   False                     False
# 2            False                   False                     False
# 3            False                   False                     False
# 4            False                   False                     False
#
#    Category_Malware  Category_Persistence  Category_PrivilegeEscalation  \
# 0              True                 False                         False
# 1             False                 False                         False
# 2             False                 False                         False
# 3             False                 False                         False
# 4             False                 False                         False
#
#    Category_Ransomware  Category_SuspiciousActivity  \
# 0                False                        False
# 1                False                        False
# 2                False                        False
# 3                False                         True
# 4                False                        False
#
#    Category_UnwantedSoftware  Category_WebExploit  EntityType_AmazonResource  \
# 0                      False                False                      False
# 1                      False                False                      False
# 2                      False                False                      False
# 3                      False                False                      False
# 4                      False                False                      False
#
#    EntityType_AzureResource  EntityType_Blob  EntityType_BlobContainer  \
# 0                     False            False                     False
# 1                     False            False                     False
# 2                     False            False                     False
# 3                     False            False                     False
# 4                     False            False                     False
#
#    EntityType_CloudApplication  EntityType_CloudLogonRequest  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    EntityType_CloudLogonSession  EntityType_File  EntityType_GenericEntity  \
# 0                         False             True                     False
# 1                         False            False                     False
# 2                         False            False                     False
# 3                         False             True                     False
# 4                         False             True                     False
#
#    EntityType_GoogleCloudResource  EntityType_IoTDevice  EntityType_Ip  \
# 0                           False                 False          False
# 1                           False                 False          False
# 2                           False                 False          False
# 3                           False                 False          False
# 4                           False                 False          False
#
#    EntityType_KubernetesCluster  EntityType_KubernetesNamespace  \
# 0                         False                           False
# 1                         False                           False
# 2                         False                           False
# 3                         False                           False
# 4                         False                           False
#
#    EntityType_Machine  EntityType_MailCluster  EntityType_MailMessage  \
# 0               False                   False                   False
# 1                True                   False                   False
# 2                True                   False                   False
# 3               False                   False                   False
# 4               False                   False                   False
#
#    EntityType_Mailbox  EntityType_MailboxConfiguration  EntityType_Malware  \
# 0               False                            False               False
# 1               False                            False               False
# 2               False                            False               False
# 3               False                            False               False
# 4               False                            False               False
#
#    EntityType_Nic  EntityType_OAuthApplication  EntityType_Process  \
# 0           False                        False               False
# 1           False                        False               False
# 2           False                        False               False
# 3           False                        False               False
# 4           False                        False               False
#
#    EntityType_RegistryKey  EntityType_RegistryValue  EntityType_SecurityGroup  \
# 0                   False                     False                     False
# 1                   False                     False                     False
# 2                   False                     False                     False
# 3                   False                     False                     False
# 4                   False                     False                     False
#
#    EntityType_Url  EntityType_User  EvidenceRole_Related  Url_1  Url_2  \
# 0           False            False                  True  False  False
# 1           False            False                 False  False  False
# 2           False            False                 False  False  False
# 3           False            False                  True  False  False
# 4           False            False                 False  False  False
#
#    Url_160396  Url_Others  AccountName_1  AccountName_2  AccountName_453297  \
# 0        True       False          False          False                True
# 1        True       False          False          False                True
# 2        True       False          False          False                True
# 3        True       False          False          False                True
# 4        True       False          False          False                True
#
#    AccountName_Others  DeviceName_1  DeviceName_4  DeviceName_153085  \
# 0               False         False         False               True
# 1               False         False         False              False
# 2               False         False         False              False
# 3               False         False         False               True
# 4               False         False         False               True
#
#    DeviceName_Others  OSFamily_1  OSFamily_2  OSFamily_3  OSFamily_5  \
# 0              False       False       False       False        True
# 1               True       False       False       False        True
# 2               True       False       False       False        True
# 3              False       False       False       False        True
# 4              False       False       False       False        True
#
#    CountryCode_1  CountryCode_2  CountryCode_242  CountryCode_Others
# 0          False          False             True               False
# 1          False          False             True               False
# 2          False          False             True               False
# 3          False          False             True               False
# 4          False          False             True               False

# %%
df_train.shape
# Out:
# (4577400, 73)
